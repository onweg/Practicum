# %%
LET = "ABCDEFGH"
NUM = "12345678"

class Pawn:
    def __init__(self, color, let, num):
        self.symbol = 'p' if color == 'black' else 'P'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        let = self.let
        num = self.num
        piece = self.symbol
        list_moves = []

        if piece == 'p':
            if (let, str(int(num)-1)) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, str(int(num)-1)))
                if num == '7' and (let, str(int(num)-2)) not in all_coordinates['white']+all_coordinates['black']:
                    list_moves.append((let, str(int(num)-2)))
            if (chr(ord(let)-1), chr(ord(num)-1)) in all_coordinates['white']:
                list_moves.append((chr(ord(let)-1), chr(ord(num)-1)))
            if (chr(ord(let)+1), chr(ord(num)-1)) in all_coordinates['white']:
                list_moves.append((chr(ord(let)+1), chr(ord(num)-1)))
        else:
            if (let, str(int(num)+1)) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, str(int(num)+1)))
                if num == '2' and (let, str(int(num)+2)) not in all_coordinates['white']+all_coordinates['black']:
                    list_moves.append((let, str(int(num)+2)))
            if (chr(ord(let)-1), chr(ord(num)+1)) in all_coordinates['black']:
                list_moves.append((chr(ord(let)-1), chr(ord(num)+1)))
            if (chr(ord(let)+1), chr(ord(num)+1)) in all_coordinates['black']:
                list_moves.append((chr(ord(let)+1), chr(ord(num)+1)))

        for x,y in list_moves.copy():
            if x not in LET or y not in NUM:
                list_moves.remove((x,y))

        return list_moves


class Horse:
    def __init__(self, color, let, num):
        self.symbol = 'n' if color == 'black' else 'N'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        let = self.let
        num = self.num
        list_moves = [( chr(ord(let)-2), chr(ord(num)-1) ),
                      ( chr(ord(let)-2), chr(ord(num)+1) ),
                      ( chr(ord(let)-1), chr(ord(num)+2) ),
                      ( chr(ord(let)-1), chr(ord(num)-2) ),
                      ( chr(ord(let)+2), chr(ord(num)-1) ),
                      ( chr(ord(let)+2), chr(ord(num)+1) ),
                      ( chr(ord(let)+1), chr(ord(num)+2) ),
                      ( chr(ord(let)+1), chr(ord(num)-2) ),]

        for x,y in list_moves.copy():
            if x not in LET or y not in NUM or ((x,y) in all_coordinates[self.color]):
                list_moves.remove((x,y))

        return list_moves

class Elephant:
    def __init__(self, color, let, num):
        self.symbol = 'b' if color == 'black' else 'B'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        list_moves = []

        let = chr(ord(self.let)+1)
        num = chr(ord(self.num)+1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let)+1)
            num = chr(ord(num)+1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = chr(ord(self.num) + 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
            num = chr(ord(num) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) + 1)
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) + 1)
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        for x,y in list_moves.copy():
            if x not in LET or y not in NUM or ((x,y) in all_coordinates[self.color]):
                list_moves.remove((x,y))

        return list_moves


class Rook:
    def __init__(self, color, let, num):
        self.symbol = 'r' if color == 'black' else 'R'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        list_moves = []

        let = chr(ord(self.let) + 1)
        num = self.num
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = self.num
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = self.let
        num = chr(ord(self.num) + 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            num = chr(ord(num) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = self.let
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white']+all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        for x,y in list_moves.copy():
            if x not in LET or y not in NUM or ((x,y) in all_coordinates[self.color]):
                list_moves.remove((x,y))

        return list_moves

class Queen:
    def __init__(self, color, let, num):
        self.symbol = 'q' if color == 'black' else 'Q'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        list_moves = []

        let = chr(ord(self.let) + 1)
        num = chr(ord(self.num) + 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) + 1)
            num = chr(ord(num) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = chr(ord(self.num) + 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
            num = chr(ord(num) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) + 1)
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) + 1)
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) + 1)
        num = self.num
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = chr(ord(self.let) - 1)
        num = self.num
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            let = chr(ord(let) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = self.let
        num = chr(ord(self.num) + 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            num = chr(ord(num) + 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        let = self.let
        num = chr(ord(self.num) - 1)
        while (let in LET and num in NUM):
            if (let, num) not in all_coordinates['white'] + all_coordinates['black']:
                list_moves.append((let, num))
            else:
                break
            num = chr(ord(num) - 1)
        if let in LET and num in NUM:
            list_moves.append((let, num))

        for x,y in list_moves.copy():
            if x not in LET or y not in NUM or ((x,y) in all_coordinates[self.color]):
                list_moves.remove((x,y))

        return list_moves

class King:
    def __init__(self, color, let, num):
        self.symbol = 'k' if color == 'black' else 'K'
        self.let = let
        self.num = num
        self.color = color

    def moves(self, all_coordinates = {'white':[], 'black':[]}):
        let = self.let
        num = self.num
        list_moves = [(chr(ord(let) + 1), chr(ord(num) + 1)),
                      (chr(ord(let) + 1), chr(ord(num))),
                      (chr(ord(let) + 1), chr(ord(num) - 1)),
                      (chr(ord(let)), chr(ord(num) - 1)),
                      (chr(ord(let) - 1), chr(ord(num) - 1)),
                      (chr(ord(let) - 1), chr(ord(num))),
                      (chr(ord(let) - 1), chr(ord(num) + 1)),
                      (chr(ord(let)), chr(ord(num) + 1)), ]

        for x, y in list_moves.copy():
            if x not in LET or y not in NUM or ((x, y) in all_coordinates[self.color]):
                list_moves.remove((x, y))
        return list_moves
